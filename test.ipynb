# %%
from ClientTools.client import UniswapClient
from datetime import datetime

client = UniswapClient(client_api_key="2f1c7a49727a459fa525610c8a03856d")

# %%
from ClientTools.client import UniswapClient

client = UniswapClient(client_api_key="xxx")

start_time = datetime(2023, 1, 1, 0, 0)  # Example: January 1, 2023, 00:00
end_time = datetime(2023, 1, 1, 1, 0)

trades_info = client.get_trades(
    symbol_1="weth", symbol_2="usdt", from_datetime=start_time, to_datetime=end_time
)

trades_info
# Out:
# [{'sender': '0x68b3465833fb72A70ecDF485E0e4C7bD8665Fc45',
#   'recipient': '0x68b3465833fb72A70ecDF485E0e4C7bD8665Fc45',
#   'amount0': -16622016577638535,
#   'amount1': 20000000,
#   'sqrtPriceX96': 2747540766141243091376081,
#   'liquidity': 6365795120611021746,
#   'tick': -205398,
#   'block_number': 16307293},
#  {'sender': '0xE592427A0AEce92De3Edee1F18E0157C05861564',
#   'recipient': '0xE592427A0AEce92De3Edee1F18E0157C05861564',
#   'amount0': -249329886597966891,
#   'amount1': 299999999,
#   'sqrtPriceX96': 2747544498049669386082516,
#   'liquidity': 6365795120611021746,
#   'tick': -205398,
#   'block_number': 16307298},
#  {'sender': '0xE592427A0AEce92De3Edee1F18E0157C05861564',
#   'recipient': '0xE592427A0AEce92De3Edee1F18E0157C05861564',
#   'amount0': -249329209284066028,
#   'amount1': 299999999,
#   'sqrtPriceX96': 2747548229958095680788951,
#   'liquidity': 6365795120611021746,
#   'tick': -205398,
#   'block_number': 16307300},
# ...
